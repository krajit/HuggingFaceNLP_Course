# %% [markdown]
# Source:
#
# https://huggingface.co/learn/nlp-course/en/chapter1/4?fw=pt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Transformers General Architecture

# %% [markdown]
# The book is a better reference for understanding transformers architecture
